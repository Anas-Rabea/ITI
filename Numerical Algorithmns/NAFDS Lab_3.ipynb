# %% [markdown]
# ## Secant Method
# - Implement the <b>Secant method</b> as a function and solve the following equation:
#     - $𝒇(𝒙)=𝒙^𝟑−𝒙^𝟐−𝟏𝟓𝒙+𝟏$,          𝒙_𝟎=𝟒.𝟓
# - Draw the functions and check out the roots.
# - Try your function with different initialization and check out the results.
# - Compare the results with the one from Newton's method.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = x = np.linspace(-5 , 5, 1000)
fun = x**3 - x**2 - 15*x + 1
plt.grid()
plt.plot(x , fun)

# %%
epsilon = 1e-8

# %%
def fun1(x):
    return  x**3 - x**2 - 15*x + 1

# %%
def secant(fun , x_0, xk_1  , epsilon ):
    x=[xk_1]
    x.append(x_0)
    for i in range(2,20):
        f_x = fun(x[i-1])
    #     print(f_x)
        fd_x = (fun(x[i-1]) - fun(x[i-2]))/(x[i-1] - x[i-2])
    #     print(fd_x)
        x.append(x[i-1] - f_x / fd_x)
    #     print(x)
        if np.linalg.norm(x[i] - x[i-1]) <= epsilon:
            print("Iteration: " ,i - 2)
            print(f"f_x() =  " , fun(x[i]))
            print("POINTS : ",x)
            print("root: ", x[i])
            break

# %%
secant(fun1 , 4.5 , 5.5 , 1e-8)
# Out:
# Iteration:  5
# f_x() =   -2.842170943040401e-14
# POINTS :  [5.5, 4.5, 4.412935323383085, 4.3773454074278275, 4.375774930082596, 4.37575386774012, 4.375753855672038, 4.375753855671945]
# root:  4.375753855671945

# %%
secant(fun1 , 4.5 , 4.51 , 1e-8)
# Out:
# Iteration:  4
# f_x() =   1.4210854715202004e-14
# POINTS :  [4.51, 4.5, 4.381356253949141, 4.375995682087235, 4.375754342564984, 4.3757538557143265, 4.375753855671946]
# root:  4.375753855671946

# %%
secant(fun1 , 4.5 , 0 , 1e-8)
# Out:
# Iteration:  9
# f_x() =   -2.842170943040401e-14
# POINTS :  [0, 4.5, -1.333333333333333, 6.545454545454546, -2.4079756397493695, -3.671133716289982, -3.31234137721203, -3.430268464695169, -3.4428134434380793, -3.442142885227578, -3.442146169027386, -3.4421461699322515]
# root:  -3.4421461699322515

# %% [markdown]
# ### *Newton*

# %%
def fun1(x):
    return  x**3 - x**2 - 15*x + 1
def fun1_d(x):
    return 3*x**2 - 2*x - 15

# %%
def newton_method(fun1,fun1_d , x0):
    x = [x0]
#     myTable = PrettyTable(["iteration", "X_0", "g(x_0)", " diff "])
    for i in range(1,10):
#         print(i)
        f_x = fun1(x[i-1])
#         print(f_x)
        f_d = fun1_d(x[i-1])
#         print(f_d)
        x.append( x[i-1] - f_x / f_d)
        if np.linalg.norm(x[i-1] - x[i]) < 0.000000001:
            print("No of iters : " , i - 1)
            break
    print("root is : ", x[-1])

# %%
newton_method(fun1 , fun1_d , 4.5)
# Out:
# No of iters :  3
# root is :  4.375753855671946

# %%
newton_method(fun1 , fun1_d ,5.5)
# Out:
# No of iters :  5
# root is :  4.375753855671946

# %%
newton_method(fun1 , fun1_d ,0)
# Out:
# No of iters :  3
# root is :  0.06639231426030472

# %%
# Secant with initial xk-1 = 5.5, epsilon = 1e-8
# Out:
# Found solution after 5 iterations.
# r = 4.375753855672038
# f(r1) = 3.097966327914037e-12

# %%
# Newton's with epsilon = 1e-8
# Out:
# Found solution after 3 iterations.
# r = 4.375753855705814
# f(r1) = 1.1410321576477145e-09

# %%
# Secant with initial xk-1 = 4.51, epsilon = 1e-8
# Out:
# Found solution after 4 iterations.
# r = 4.3757538557143265
# f(r1) = 1.427807205800491e-09

# %%
# Secant with initial xk-1 = 0, epsilon = 1e-8
# Out:
# Found solution after 10 iterations.
# r = -3.4421461699322515
# f(r1) = -2.842170943040401e-14

# %% [markdown]
# ## Newton's Method Optimization
# ### Single Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐−𝟏𝟓𝒙+𝟏$,
# - Draw the functions and check out the minimum.
# - Draw the 1st derivative of the function and check out the root.
# - Draw 2nd derivative of the function and check out the sign at the minimum.
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results with Gradient descent.

# %%
x = np.linspace(-60 , 70, 1000)
f_x = x**2 - 15*x + 1
plt.grid()
plt.plot(x , f_x)

# %%
x = np.linspace(-60 , 70, 1000)
f_x = 2*x - 15                         #x**2 - 15*x + 1
plt.grid()
plt.plot(x , f_x)

# %%
# get root of above function to represent the min of original function
def fun2(x):
    return 2*x - 15  #    x**2 - 15*x + 1

def fun2_d(x):
    return 2

def newton_method(fun,fun_d,alpha , x0):
    x = [x0]
#     myTable = PrettyTable(["iteration", "X_0", "g(x_0)", " diff "])
    for i in range(1,10):
#         print(i)
        f_x = fun(x[i-1])
#         print(f_x)
        f_d = fun_d(x[i-1])
#         print(f_d)
        x.append( x[i-1] - alpha * (f_x / f_d))
        if np.linalg.norm(x[i-1] - x[i]) < 0.1:
            print("No of iters : " , i - 1)
            break
    print("root is : ", x[-1])

# %%
# Newton's method withot learning rate
newton_method(fun2 , fun2_d ,1, 40)
# Out:
# No of iters :  1
# root is :  7.5

# %%
# Newton's method with learning rate = 0.8, x0=40, epsilon = 0.1
newton_method(fun2 , fun2_d ,0.8, 40)
# Out:
# No of iters :  4
# root is :  7.5104

# %% [markdown]
# ### *Using Gredient*

# %%
def GD(fun_d , alpha , x_0 , epsilon):
    x = [x_0]
    for i in range(1,1000):
#         print(x[i-1])
        x.append(x[i-1] - alpha* fun_d(x[i-1]))
#         print( fun_d(x[i-1]), x)
#         print(x[i] - x[i-1])
        if np.linalg.norm(fun_d(x[i-1])) < epsilon:
            print("No of iters : " , i-1 )
            break
    print("root is : ", x[-1])

# %%
GD(fun2 , 0.01, 40 ,0.1)
# Out:
# No of iters :  321
# root is :  7.548604864188269

# %%
x = np.linspace(-60 , 70, 1000)
f_x = [2]*1000             #x**2 - 15*x + 1
plt.grid()
plt.plot(x , f_x)

# %%
f = lambda x: x**2 - 15*x +1
Df = lambda x: 2*x -15
DDf = lambda x: 2

# %%
# Gradient descent with learning rate = 0.01, x0=40, epsilon = 0.1
# Out:
# Found solution after 321 iterations.
# (7.549596800192111, 0.09919360038422198)

# %%
# Newton's method without learning rate, x0=40, epsilon = 0.1
# Out:
# Found solution after 1 iterations.
# (7.5, 0.0)

# %%
# Newton's method with learning rate = 0.8, x0=40, epsilon = 0.1
# Out:
# Found solution after 5 iterations.
# (7.5104, 0.020799999999999486)

# %% [markdown]
# ### Multi Variable
# - Implement the <b>Gradient decent and Newton's method</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐y$
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results with Gradient descent.

# %%
from sympy import *
from sympy.plotting import plot3d

# %%
x,y = symbols('x y')
f = x**2 + y**2
plot3d(f,size=(10,7))

# %%
x,y = symbols('x y')
f = x**2 + x * y + y**2
plot3d(f,size=(10,7))

# %%
x,y = symbols('x y')
f = x**2 * y
plot3d(f,size=(10,7))

# %%
vect = np.array([10 ,10])
def fun1_d(vect):
    return np.array([2]*np.array(vect))
def fun1_2d(vect):
    return np.array([2]*len(vect))

# %%
fun1_d(vect)
# Out:
# array([20, 20])

# %%
fun1_2d(vect)
# Out:
# array([2, 2])

# %%
np.array([2]*2)
# Out:
# array([2, 2])

# %%
# # new_vect = np.array()
# vect_list = []
# for i in range(1 , 1000):
#     new_vect = vect - 0.1 * fun1_d(vect)
#     vect_list.append(new_vect)
#     if np.linalg.norm(fun1_d(vect)) < 0.001: break
#     vect = new_vect
# print("iteration",i-1 , vect_list[-2:])

# %% [markdown]
# ### *Multi_GD*

# %%
vect = np.array([10 ,10])
def Multi_GD(fun_d , vect_0 ,alpha):
    vect_list = [vect_0]
    for i in range(1 , 1000):
        new_vect = vect_0 - alpha * fun_d(vect_0)
        vect_list.append(new_vect)
        if np.linalg.norm(fun_d(vect_list[-1])) < 0.001: break
        vect_0 = new_vect
    print("iteration",i-1 , vect_list[-1])

# %% [markdown]
# ### *First equation*

# %%
Multi_GD(fun1_d,vect ,0.1)
# Out:
# iteration 45 [0.00034845 0.00034845]

# %% [markdown]
# ### *Multi_Newton*

# %%
# # new_vect = np.array()
# vect = np.array([10 ,10])
# vect_list = []
# for i in range(1 , 1000):
#     new_vect = vect -  (fun1_d(vect)/fun1_2d(vect))
#     vect_list.append(new_vect)
#     if np.linalg.norm(fun1_d(vect)) < 0.001: break
#     vect = new_vect
# print("iteration",i-1 , vect_list[-2:])

# %%
vect = np.array([10 ,10])
def Multi_Newton(fun_d , fun_2d , alpha , vect_0):
    vect_list = [vect_0]
    for i in range(1 , 1000):
        new_vect = vect_0 - alpha * (fun_d(vect)/fun_2d(vect))
        vect_list.append(new_vect)
#         print(vect_list)
        if np.linalg.norm(fun_d(vect_list[i])) < 0.001:
            break
        vect_0 = new_vect
    print("iteration",i , vect_list[:])

# %%
vect = np.array([10 ,10])
Multi_Newton(fun1_d , fun1_2d,1 , vect)
# Out:
# iteration 1 [array([10, 10]), array([0., 0.])]

# %%
vect = np.array([10 ,10])
Multi_Newton(fun1_d , fun1_2d, 0.5 , vect)
# Out:
# iteration 2 [array([10, 10]), array([5., 5.]), array([0., 0.])]

# %% [markdown]
# ### *Using hussien*

# %%
def fun1_d(vect):
    return np.array([2]*np.array(vect))
def fun1_2d(vect):
    return np.array([2]*len(vect))

# %%
vect = np.array([10 ,10])

hessian1 = lambda x:np.matrix([[2,0],[0,2]])

# %%
# vect = np.array([10 ,10])

# fun1_d(np.array(vect))

# %%
# vect = np.array([10 ,10])

# %%
# vect = np.array([10 ,10])
# x = hessian1(vect)
# x[0]

# %%
# First function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
vect = np.array([10 ,10])
vect_list = []
for i in range(1 , 1000):
    vect = vect -  np.linalg.inv(hessian1(vect)) @ fun1_d(vect)* 1
    vect = vect.getA1()
    vect_list.append(vect)
    if np.linalg.norm(fun1_d(vect)) < 0.001:
        break
#     print(fun1_d(vect))
#     print(i)
    vect = vect.getA1()
    vect_list.append(vect)
    
#     vect = new_vect
print("iteration",i , vect_list[:])
print("gredient : ", fun1_d(vect) )
# Out:
# iteration 1 [array([0., 0.])]
# gredient :  [0. 0.]

# %%
# First function
# Multi-variable Newton's method with learning rate 0.5, 
# x0=(10,10), epsilon = 0.001
vect = np.array([10 ,10])
vect_list = []
for i in range(1 , 1000):
    vect = vect -  np.linalg.inv(hessian1(vect)) @ fun1_d(vect)* 0.5
    if np.linalg.norm(fun1_d(vect)) < 0.001:
        break
#     print(fun1_d(vect))
#     print(i)
    vect = vect.getA1()
    vect_list.append(vect)
    
#     vect = new_vect
print("iteration",i , vect_list[-2])
print("gredient : ", fun1_d(vect) )
# Out:
# iteration 15 [0.0012207 0.0012207]
# gredient :  [[0.00061035 0.00061035]]

# %% [markdown]
# ### *2nd equarion*

# %%
def fun2_d(vect):
    return np.array([2*vect[0]+vect[1] , 2*vect[1]+vect[0]])

# %%
# Second function
# Multi-variable Gradient descent with learning rate = 0.5,
# x0=(10,10), epsilon = 0.001

vect = np.array([10 ,10])

Multi_GD(fun2_d,vect ,0.5)
# Out:
# iteration 15 [0.00015259 0.00015259]

# %%
# vect = np.array([10 ,10])

# fun2_d(vect)
# fun1_2d(vect)

# %%
hessian2 = lambda x:np.matrix([[2,1],[1,2]])

# %%
vect = np.array([10 ,10])
fun2_d(vect)
# Out:
# array([30, 30])

# %%
# vect = np.array([10 ,10])

# hessian2(vect)

# %%
# vect = np.array([10 ,10])
# np.linalg.norm(fun2_d(vect))

# %%
 fun2_d(vect)
# Out:
# array([30, 30])

# %%
y = hessian2(vect)
y[0]
# Out:
# matrix([[2, 1]])

# %%
fun2_d(vect)
# Out:
# array([30, 30])

# %%
fd6(vect)
# Out:
# array([30, 30])

# %%
hessian2(vect)
# Out:
# matrix([[2, 1],
#         [1, 2]])

# %%
fd6 = lambda x: np.array([2*x[0] + x[1],x[0]+2*x[1]])
hessian2 = lambda x:np.matrix([[2,1],[1,2]])
def multi_newton_with_learningrate(x,fd,hessian,eps,lr):

    i=0
    while np.sqrt(fd(x)[0]**2+fd(x)[1]**2) >= eps:
        x = x - np.linalg.inv(hessian(x)) @ fd(x) * lr
#         print(x)
        x= x.getA1() # to flatten the matrix
#         print(x)
        i+=1
    return x ,i,fd(x)

# %%
x_0 = np.array([10,10])
x ,i,gd= multi_newton_with_learningrate( x_0,fun2_d,hessian2,0.001,1)
print("iterations = ",i)
print("x = ",x)
print("gredient",gd)
# Out:
# iterations =  1
# x =  [0. 0.]
# gredient [0. 0.]

# %%
x_0 = np.array([10,10])
x ,i,gd= multi_newton_with_learningrate( x_0,fun2_d,hessian2,0.001,0.5)
print("iterations = ",i)
print("x = ",x)
print("gredient",gd)
# Out:
# iterations =  16
# x =  [0.00015259 0.00015259]
# gredient [0.00045776 0.00045776]

# %%
# vect = np.array([10 ,10])
# x = vect -  np.linalg.inv(hessian2(vect)) @ fd6(vect)* 1
# # np.linalg.norm(fun2_d(x)
# # np.array(x)
# fd6(np.array(x))

# %%
# # Second function
# # Multi-variable Newton's method without learning rate, 
# # x0=(10,10), epsilon = 0.001

# vect = np.array([10 ,10])
# vect_list = []
# for i in range(1 , 1000):
#     vect = vect -  np.linalg.inv(hessian2(vect)) @ fun2_d(vect)* 1
#     if np.linalg.norm(fun2_d(vect)) < 0.001:
#         break
# #     print(fun1_d(vect))
#     print(i)
#     vect = vect.getA1()
#     vect_list.append(vect)
    
# #     vect = new_vect
# print("iteration",i , vect_list[:])
# print("gredient : ", fun2_d(vect) )

# %% [markdown]
# ### *3rd equation*

# %%
vect = np.array([10 ,10])

# %%
def fun3_d(vect):
    return np.array([2*vect[0]*vect[1] , vect[0]**2])

# %%
hessian3 = lambda x:np.matrix([[2*x[1] , 2*x[0]],[2*x[0] , 0]])

# %%
vect = np.array([10 ,10])

x ,i,gd= multi_newton_with_learningrate(vect,fun3_d,hessian3,0.001,1)
print("iterations = ",i)
print("x = ", x)
print("gredient",gd)
# Out:
# iterations =  9
# x =  [0.01953125 0.01953125]
# gredient [0.00076294 0.00038147]

# %%
np.linalg.inv(hessian3(vect))
# Out:
# matrix([[ 0.  ,  0.05],
#         [ 0.05, -0.05]])

# %% [markdown]
# ### *Another solution*

# %%
vect = np.array([10 ,10])
vect_list = []
for i in range(1 , 1000):
    vect = vect -  np.linalg.inv(hessian3(vect)) @ fun3_d(vect)* 1
    vect = vect.getA1()
    vect_list.append(vect)
    if np.linalg.norm(fun3_d(vect_list[-1])) < 0.001:
        break
#     print(fun1_d(vect))
#     print(i)
    
    
    
#     vect = new_vect
print("iteration",i , vect_list[-1])
print("gredient : ", fun3_d(vect) )
# Out:
# iteration 9 [0.01953125 0.01953125]
# gredient :  [0.00076294 0.00038147]

# %% [markdown]
# ### *Multi_GD*

# %%
# Third function
# Multi-variable Gradient descent with learning rate = 0..01,
# x0=(10,10), epsilon = 0.001

vect = np.array([10 ,10])
Multi_GD(fun3_d,vect ,0.01)
# Out:
# iteration 78 [6.80598421e-05 6.85061189e+00]

# %%
# First function
# Multi-variable Gradient descent with learning rate = 0.1,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 46 iterations.
# (array([0.00034845, 0.00034845]), array([0.0006969, 0.0006969]))

# %%
# First function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 1 iterations.
# (array([0., 0.]), array([0., 0.]))

# %%
# First function
# Multi-variable Newton's method with learning rate = 0.5, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 15 iterations.
# (array([0.00030518, 0.00030518]), array([0.00061035, 0.00061035]))

# %%
# Second function
# Multi-variable Gradient descent with learning rate = 0.5,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 16 iterations.
# (array([0.00015259, 0.00015259]), array([0.00045776, 0.00045776]))

# %%
# Second function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 1 iterations.
# (array([0., 0.]), array([0., 0.]))

# %%
# First function
# Multi-variable Newton's method with learning rate = 0.9, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 5 iterations.
# (array([0.0001, 0.0001]), array([0.0003, 0.0003]))

# %%
# Third function
# Multi-variable Gradient descent with learning rate = 0..01,
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 79 iterations.
# (array([6.80598421e-05, 6.85061189e+00]),
#  array([9.32503127e-04, 4.63214210e-09]))

# %%
# Third function
# Multi-variable Newton's method without learning rate, 
# x0=(10,10), epsilon = 0.001
# Out:
# Found solution after 9 iterations.
# (array([0.01953125, 0.01953125]), array([0.00076294, 0.00038147]))

# %% [markdown]
# ## BFGS
# - Implement the <b>BFGS</b> as a function and find the minimum of the following function:
#     - $𝒇(𝒙)=𝒙^𝟐+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐+xy+y^2$
#     - $𝒇(𝒙)=𝒙^𝟐y$
# - The stop condition is grad < epsilon.
# - Try different epsilons and initial conditions.
# - Compare the results from Gradient descent and Newton's method.

# %%
def fun1_d(vect):
    return np.array([2*vect[0] , 2*vect[1]])
def fun2_d(vect):
    return np.array([2*vect[0]+vect[1] , 2*vect[1]+vect[0]])
def fun3_d(vect):
    return np.array([2*vect[0]*vect[1] , vect[0]**2])

# %%
# B1_inverse =

# %%
x1 = np.array([10,10])
x0 = np.array([9,9])
x_list = [x0 , x1]
x_list
# Out:
# [array([9, 9]), array([10, 10])]

# %%
delta_x  = (x_list[1] - x_list[0]).reshape(-1 , 1)
delta_x
# Out:
# array([[1],
#        [1]])

# %%
vect = np.array([10 ,10])
y = (fun1_d(x1) - fun1_d(x0)).reshape(-1,1)
# (np.eye(2) - (x @ y.T / y.T @ x)) @ np.eye(2) @ (np.eye(2) - (y @ x.T / y.T @ x))   @ fun1_d(x1)
y
# Out:
# array([[2],
#        [2]])

# %%
delta_x @ y.T
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
delta_x @ y.T
# Out:
# array([[2, 2],
#        [2, 2]])

# %%
y.T @ x
# Out:
# array([nan])

# %%
(np.eye(2) - (y @ delta_x.T / y.T @ delta_x))
# Out:
# array([[-1., -2.],
#        [-2., -1.]])

# %%
(np.eye(2) - (delta_x @ y.T / y.T @ delta_x)) @ np.eye(2) @ (np.eye(2) - (y @ delta_x.T / y.T @ delta_x))  + (delta_x @ delta_x.T / y.T @ delta_x)
# Out:
# array([[6., 5.],
#        [5., 6.]])

# %%
B_inverse = (np.eye(2) - (delta_x @ y.T / y.T @ delta_x)) @ np.eye(2) @ (np.eye(2) - (y @ delta_x.T / y.T @ delta_x))  + (delta_x @ delta_x.T / y.T @ delta_x)
B_inverse
# Out:
# array([[6., 5.],
#        [5., 6.]])

# %%
# Out:
# (2, 1)

# %%
def BFGS(x0 , x1 ,fun1_d , alpha = 1):
    x_list = [x0 , x1]
    delta_x  = (x_list[1] - x_list[0]).reshape(-1 , 1)
    y = (fun1_d(x1) - fun1_d(x0)).reshape(-1,1)
    vect = x1
    B_initial = np.eye(2)
    vect_list = [x1]
    for i in range(1, 100):
                       # I                                                          # I 
        B_inverse = ((np.eye(2) - (delta_x @ y.T) / (y.T @ delta_x)) @ B_initial @ (np.eye(2) - (y @ delta_x.T) / (y.T @ delta_x)))  + ((delta_x @ delta_x.T) / (y.T @ delta_x))
        print(B_inverse)
        vect = np.array(vect) - B_inverse @ fun1_d(vect) * alpha
        print(vect)
        vect_list.append(vect)
        if np.linalg.norm(fun1_d(vect)) < 0.001:
            break
        delta_x = (vect_list[-1] - vect_list[-2]).reshape(-1 , 1)
        y = (fun1_d(vect_list[-1]) - fun1_d(vect_list[-2])).reshape(-1 , 1)
        B_initial = B_inverse
    print("final vector : " , vect, " and no of iteration : ", i, " gred :  " ,fun1_d(vect) )

# %%
 BFGS(x0 , x1 ,fun1_d , 1)
# Out:
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [0. 0.]
# final vector :  [0. 0.]  and no of iteration :  1  gred :   [0. 0.]

# %%
# 0.9 learning rate 
BFGS(x0 , x1 ,fun1_d , 0.9)
# Out:
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [1. 1.]
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [0.1 0.1]
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [0.01 0.01]
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [0.001 0.001]
# [[ 0.75 -0.25]
#  [-0.25  0.75]]
# [1.e-04 1.e-04]
# final vector :  [1.e-04 1.e-04]  and no of iteration :  5  gred :   [0.0002 0.0002]

# %%
BFGS(x0 , x1 ,fun2_d , 1)
# Out:
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [1.77635684e-15 1.77635684e-15]
# final vector :  [1.77635684e-15 1.77635684e-15]  and no of iteration :  1  gred :   [5.32907052e-15 5.32907052e-15]

# %%
BFGS(x0 , x1 ,fun2_d , 0.9)
# Out:
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [1. 1.]
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [0.1 0.1]
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [0.01 0.01]
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [0.001 0.001]
# [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# [0.0001 0.0001]
# final vector :  [0.0001 0.0001]  and no of iteration :  5  gred :   [0.0003 0.0003]

# %%
BFGS(x0 , x1 ,fun3_d , 1)
# Out:
# [[ 0.23976608 -0.42690058]
#  [-0.42690058  0.90643275]]
# [4.73684211 4.73684211]
# [[ 0.24484127 -0.4218254 ]
#  [-0.4218254   0.91150794]]
# [3.21428571 3.21428571]
# [[ 0.264145   -0.40252167]
#  [-0.40252167  0.93081166]]
# [1.91489362 1.91489362]
# [[ 0.28720988 -0.37945679]
#  [-0.37945679  0.95387654]]
# [1.2 1.2]
# [[ 0.32923497 -0.33743169]
#  [-0.33743169  0.99590164]]
# [0.73770492 0.73770492]
# [[ 0.39424704 -0.27241963]
#  [-0.27241963  1.06091371]]
# [0.45685279 0.45685279]
# [[ 0.50126553 -0.16540114]
#  [-0.16540114  1.1679322 ]]
# [0.28213166 0.28213166]
# [[0.6732917  0.00662504]
#  [0.00662504 1.33995837]]
# [0.1744186 0.1744186]
# [[0.95233533 0.28566866]
#  [0.28566866 1.619002  ]]
# [0.10778443 0.10778443]
# [[1.40340489 0.73673822]
#  [0.73673822 2.07007155]]
# [0.06661732 0.06661732]
# [[2.13351801 1.46685134]
#  [1.46685134 2.80018467]]
# [0.04117109 0.04117109]
# [[3.31470068 2.64803401]
#  [2.64803401 3.98136734]]
# [0.02544529 0.02544529]
# ...

# %%
## First function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[20.]
#  [20.]]
# Dfxn
#  [[18.]
#  [18.]]
# 25.45584412271571
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.]
#  [0.]]
# Dfxn_1
#  [[18.]
#  [18.]]
# Dfxn
#  [[0.]
#  [0.]]
# 0.0
# *****
# Found solution after 1 iterations.
# (array([[0.],
#         [0.]]),
#  array([[0.],
#         [0.]]))

# %%
## First function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001, 
## learning rate =0.9
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[20.]
#  [20.]]
# Dfxn
#  [[18.]
#  [18.]]
# 25.45584412271571
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.9]
#  [0.9]]
# Dfxn_1
#  [[18.]
#  [18.]]
# Dfxn
#  [[1.8]
#  [1.8]]
# 2.545584412271567
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.9]
#  [0.9]]
# xn
# : [[0.09]
#  [0.09]]
# Dfxn_1
#  [[1.8]
#  [1.8]]
# Dfxn
#  [[0.18]
#  [0.18]]
# 0.2545584412271567
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.09]
#  [0.09]]
# xn
# : [[0.009]
#  [0.009]]
# Dfxn_1
#  [[0.18]
#  [0.18]]
# Dfxn
#  [[0.018]
#  [0.018]]
# 0.025455844122715655
# *****
# B_inv
#  [[ 0.75 -0.25]
#  [-0.25  0.75]]
# ****************
# xn_1:
#  [[0.009]
#  [0.009]]
# xn
# : [[0.0009]
#  [0.0009]]
# Dfxn_1
#  [[0.018]
#  [0.018]]
# Dfxn
#  [[0.0018]
#  [0.0018]]
# 0.0025455844122715655
# *****
# B_inv
# ...

# %%
## Second function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[30.]
#  [30.]]
# Dfxn
#  [[27.]
#  [27.]]
# 38.18376618407357
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[1.77635684e-15]
#  [1.77635684e-15]]
# Dfxn_1
#  [[27.]
#  [27.]]
# Dfxn
#  [[5.32907052e-15]
#  [5.32907052e-15]]
# 7.53644380168212e-15
# *****
# Found solution after 1 iterations.
# (array([[1.77635684e-15],
#         [1.77635684e-15]]),
#  array([[5.32907052e-15],
#         [5.32907052e-15]]))

# %%
## Second function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001,
## learning rate  = 0.9
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[30.]
#  [30.]]
# Dfxn
#  [[27.]
#  [27.]]
# 38.18376618407357
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[0.9]
#  [0.9]]
# Dfxn_1
#  [[27.]
#  [27.]]
# Dfxn
#  [[2.7]
#  [2.7]]
# 3.8183766184073655
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.9]
#  [0.9]]
# xn
# : [[0.09]
#  [0.09]]
# Dfxn_1
#  [[2.7]
#  [2.7]]
# Dfxn
#  [[0.27]
#  [0.27]]
# 0.38183766184073553
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.09]
#  [0.09]]
# xn
# : [[0.009]
#  [0.009]]
# Dfxn_1
#  [[0.27]
#  [0.27]]
# Dfxn
#  [[0.027]
#  [0.027]]
# 0.038183766184073605
# *****
# B_inv
#  [[ 0.66666667 -0.33333333]
#  [-0.33333333  0.66666667]]
# ****************
# xn_1:
#  [[0.009]
#  [0.009]]
# xn
# : [[0.0009]
#  [0.0009]]
# Dfxn_1
# ...

# %%
## Third function
## BFGD with xk-1 = (10,10) and x0 = (9,9), epsilon = 0.001
# Out:
# xn_1:
#  [[10.]
#  [10.]]
# xn
# : [[9.]
#  [9.]]
# Dfxn_1
#  [[200.]
#  [100.]]
# Dfxn
#  [[162.]
#  [ 81.]]
# 181.12150617748296
# *****
# B_inv
#  [[ 0.23976608 -0.42690058]
#  [-0.42690058  0.90643275]]
# ****************
# xn_1:
#  [[9.]
#  [9.]]
# xn
# : [[4.73684211]
#  [4.73684211]]
# Dfxn_1
#  [[162.]
#  [ 81.]]
# Dfxn
#  [[44.87534626]
#  [22.43767313]]
# 50.172162376034116
# *****
# B_inv
#  [[ 0.24648787 -0.4201788 ]
#  [-0.4201788   0.91315453]]
# ****************
# xn_1:
#  [[4.73684211]
#  [4.73684211]]
# xn
# : [[3.10344828]
#  [3.10344828]]
# Dfxn_1
#  [[44.87534626]
#  [22.43767313]]
# Dfxn
#  [[19.2627824]
#  [ 9.6313912]]
# 21.53644544322043
# *****
# B_inv
#  [[ 0.26473765 -0.40192901]
#  [-0.40192901  0.93140432]]
# ****************
# xn_1:
#  [[3.10344828]
#  [3.10344828]]
# xn
# : [[1.875]
#  [1.875]]
# Dfxn_1
#  [[19.2627824]
#  [ 9.6313912]]
# Dfxn
#  [[7.03125 ]
#  [3.515625]]
# 7.861176483398071
# *****
# B_inv
#  [[ 0.28917749 -0.37748918]
# ...
